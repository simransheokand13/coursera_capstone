# %% [markdown]
# # This  is my First notebook of Applied Data Science Capstone Course for Peer-graded Assihnment:Capstone Project Notebook of Week 1

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
